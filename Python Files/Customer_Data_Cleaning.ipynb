# %%
import numpy as np
import pandas as pd

# %%
import chardet
with open(r"C:\Users\sivas\OneDrive\Documents\Data Analyst Projects\Project 2\Dataset\Sample - Superstore.csv","rb") as f:
    dt = f.read(50000)
    result = chardet.detect(dt)
print(result)
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}

# %%
data = pd.read_csv(r"C:\Users\sivas\OneDrive\Documents\Data Analyst Projects\Project 2\Dataset\Sample - Superstore.csv",encoding = "windows-1252")

# %%
data.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Unnamed: 17       object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
data["Row ID"] = data["Row ID"].astype("string")

# %%
data["Order ID"] = data["Order ID"].astype("string")

# %%
data.isnull().sum()
# Out:
# Row ID              0
# Order ID            0
# Order Date          0
# Ship Date           0
# Ship Mode           0
# Customer ID         0
# Customer Name       0
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code         0
# Region              0
# Product ID          0
# Category            0
# Sub-Category        0
# Product Name        0
# Unnamed: 17      9993
# Sales               0
# Quantity            0
# Discount            0
# Profit              0
# dtype: int64

# %%
data.drop("Unnamed: 17", axis = 1, inplace = True)

# %%
data["Ship Mode"] = data["Ship Mode"].astype('string')
data["Customer ID"] = data["Customer ID"] .astype('string')
data["Customer Name"] = data["Customer Name"] .astype('string')
data["Segment"] = data["Segment"] .astype('category')
data["Country"] = data["Country"] .astype('string')
data["City"] = data["City"] .astype('string')
data["State"] = data["State"] .astype('string')
data["Postal Code"] = data["Postal Code"] .astype('string')
data["Region"] = data["Region"] .astype('category')
data["Product ID"]  = data["Product ID"] .astype('string')
data["Category"]  = data["Category"] .astype('category')
data["Sub-Category"]  = data["Sub-Category"] .astype('string')
data["Product Name"]  = data["Product Name"] .astype('string')

# %%
data["Order Date"] = pd.to_datetime(data["Order Date"],dayfirst =True)

# %%
data.loc[pd.to_datetime(data["Ship Date"],errors ="coerce").isna(), "Ship Date"]
# Out:
# 2       16-06-2016
# 3       16-06-2017
# 4       16-06-2018
# 5       16-06-2019
# 6       16-06-2020
#            ...
# 9984    23-05-2015
# 9985    23-05-2015
# 9987    21-11-2017
# 9988    21-11-2017
# 9989    23-01-2014
# Name: Ship Date, Length: 6096, dtype: object

# %%
data["Ship Date"] = pd.to_datetime(data["Ship Date"], dayfirst = True)

# %%
data.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
data = data.apply(lambda x : x.str.strip() if x.dtype == "string" else x)

# %%
mask = data.select_dtypes(include = "string").apply(lambda x : x.str.contains(r'[^a-zA-z0-9 ]', regex = True, na = False))

# %%
mask. any()
# Out:
# Row ID           False
# Order ID          True
# Ship Mode        False
# Customer ID       True
# Customer Name     True
# Country          False
# City             False
# State            False
# Postal Code      False
# Product ID        True
# Sub-Category     False
# Product Name      True
# dtype: boolean

# %%
data.dtypes
# Out:
# Row ID           string[python]
# Order ID         string[python]
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode        string[python]
# Customer ID      string[python]
# Customer Name    string[python]
# Segment                category
# Country          string[python]
# City             string[python]
# State            string[python]
# Postal Code      string[python]
# Region                 category
# Product ID       string[python]
# Category               category
# Sub-Category     string[python]
# Product Name     string[python]
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
data["Order Date"]. min()
# Out:
# Timestamp('2014-01-03 00:00:00')

# %%
data["Order Date"].max()
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
data["Ship Date"].min()
# Out:
# Timestamp('2014-01-04 00:00:00')

# %%
data["Ship Date"].max()
# Out:
# Timestamp('2026-06-16 00:00:00')

# %%
data["Ship Date"].between("2018-01-01","2018-12-31").sum()
# Out:
# 43

# %%
data["Order Date"].between("2018-01-01","2018-12-31").sum()
# Out:
# 0

# %%
data.select_dtypes(include= "datetime").apply(lambda x : x > "2018-12-31" ).sum()
# Out:
# Order Date    0
# Ship Date     8
# dtype: int64

# %%
data = data[data["Ship Date"].between("2014-01-01", "2018-12-31")]

# %%
data["Ship Date"].min()
# Out:
# Timestamp('2014-01-04 00:00:00')

# %%
data["Ship Date"].max()
# Out:
# Timestamp('2018-06-16 00:00:00')

# %%
data["Segment"].unique()
# Out:
# ['Consumer', 'Corporate', 'Home Office']
# Categories (3, object): ['Consumer', 'Corporate', 'Home Office']

# %%
data["Country"].unique()
# Out:
# <StringArray>
# ['United States']
# Length: 1, dtype: string

# %%
pd.reset_option("display.max_rows")

# %%
data["City"].unique()
# Out:
# <StringArray>
# [        'Henderson',       'Los Angeles',   'Fort Lauderdale',
#            'Seattle',        'Fort Worth',           'Madison',
#        'West Jordan',     'San Francisco',           'Fremont',
#       'Philadelphia',
#  ...
#         'Hagerstown',       'East Orange', 'Arlington Heights',
#             'Oswego',       'Coon Rapids',      'San Clemente',
#    'San Luis Obispo',        'Springdale',              'Lodi',
#              'Mason']
# Length: 531, dtype: string

# %%
data["State"].unique()
# Out:
# <StringArray>
# [            'Kentucky',           'California',              'Florida',
#            'Washington',                'Texas',            'Wisconsin',
#                  'Utah',             'Nebraska',         'Pennsylvania',
#              'Illinois',            'Minnesota',             'Michigan',
#              'Delaware',              'Indiana',             'New York',
#               'Arizona',             'Virginia',            'Tennessee',
#               'Alabama',       'North Carolina',       'South Carolina',
#                'Oregon',             'Colorado',                 'Iowa',
#                  'Ohio',             'Missouri',             'Oklahoma',
#            'New Mexico',            'Louisiana',          'Connecticut',
#            'New Jersey',        'Massachusetts',              'Georgia',
#                'Nevada',         'Rhode Island',          'Mississippi',
#              'Arkansas',              'Montana',        'New Hampshire',
# ...

# %%
data["Region"].unique()
# Out:
# ['South', 'West', 'Central', 'East']
# Categories (4, object): ['Central', 'East', 'South', 'West']

# %%
data["Category"].unique()
# Out:
# ['Furniture', 'Office Supplies', 'Technology']
# Categories (3, object): ['Furniture', 'Office Supplies', 'Technology']

# %%
data["Sub-Category"].unique()
# Out:
# <StringArray>
# [  'Bookcases',      'Chairs',      'Labels',      'Tables',     'Storage',
#      'Binders',  'Appliances',         'Art',      'Phones', 'Accessories',
#  'Furnishings',   'Envelopes',       'Paper',   'Fasteners',    'Supplies',
#     'Machines',     'Copiers']
# Length: 17, dtype: string

# %%
data.to_csv(r"C:\Users\sivas\OneDrive\Documents\Data Analyst Projects\Project 2\cleaned_superstore using python.csv")
